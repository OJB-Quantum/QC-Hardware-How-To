# %% [markdown]
# <a href="https://colab.research.google.com/github/OJB-Quantum/QC-Hardware-How-To/blob/main/Jupyter%20Notebook%20Scripts/Quantum_Circuit_Rendering_with_Qiskit_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Authored by Onri Jay Benally (2025)
#
# Open Access (CC-BY-4.0)

# %%
# !pip install qutip qutip-qip pylatexenc qiskit qiskit_aer -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.5/28.5 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 100.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 71.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.quantum_info import Operator
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# %%
# Onri prefers using rcParams to increase the quality of all plots to be higher than the default settings.
# This only needs to be done once at beginning of every Jupyter Notebook.
import matplotlib as plt
plt.rcParams['figure.dpi'] = 250

# %%
circuit = QuantumCircuit(1)
circuit.x(0)
display(circuit.draw(output="mpl"))
display(Operator.from_circuit(circuit).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  1 & 0  \\
#  \end{bmatrix}
# $$

# %%
circuit = QuantumCircuit(1)
circuit.x(0)
display(circuit.draw(output="mpl"))
display(Operator.from_circuit(circuit).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  1 & 0  \\
#  \end{bmatrix}
# $$

# %%
circuit = QuantumCircuit(2)
circuit.x(0)
circuit.y(0)
circuit.z(0)
circuit.h(0)
circuit.cx(0,1)
display(circuit.draw(output="mpl"))
display(Operator.from_circuit(circuit).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# - \frac{\sqrt{2} i}{2} & - \frac{\sqrt{2} i}{2} & 0 & 0  \\
#  0 & 0 & - \frac{\sqrt{2} i}{2} & \frac{\sqrt{2} i}{2}  \\
#  0 & 0 & - \frac{\sqrt{2} i}{2} & - \frac{\sqrt{2} i}{2}  \\
#  - \frac{\sqrt{2} i}{2} & \frac{\sqrt{2} i}{2} & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
circuit = QuantumCircuit(1)
circuit.h(0)
circuit.s(0)
circuit.h(0)
circuit.t(0)

display(circuit.draw(output="mpl"))
display(Operator.from_circuit(circuit).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# \frac{1}{2} + \frac{i}{2} & \frac{1}{2} - \frac{i}{2}  \\
#  \frac{\sqrt{2}}{2} & \frac{\sqrt{2} i}{2}  \\
#  \end{bmatrix}
# $$

# %%
X = QuantumRegister(1, "X")
Y = QuantumRegister(1, "Y")
circuit = QuantumCircuit(Y,X)
circuit.h(Y)
circuit.cx(Y, X)

display(circuit.draw(output="mpl"))
display(Operator.from_circuit(circuit).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0 & 0  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2}  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2} & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt

# Define the Pauli-X gate
X_gate = qt.sigmax()

# Define the initial state |0⟩
initial_state = qt.basis(2, 0)

# Apply the X gate
final_state = X_gate * initial_state

# Compute the Bloch vector
bloch_vector = [qt.expect(qt.sigmax(), final_state),
                qt.expect(qt.sigmay(), final_state),
                qt.expect(qt.sigmaz(), final_state)]

# Create a Bloch sphere instance
bloch = qt.Bloch()

# Add the Bloch vector
bloch.add_vectors(bloch_vector)

# Render the Bloch sphere
bloch.show()
